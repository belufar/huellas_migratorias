# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd


file_path = '/content/drive/My Drive/GRAFICA/base-2022-comunas.csv'


df = pd.read_csv(file_path, encoding='latin1')

# %%
print(df.head())
# Out:
#   SEXO     EDAD      PAIS  AÑO ESTIMACION                     REGION  \
# 0    H  00 A 04  ALEMANIA            2018                        NaN
# 1    H  00 A 04  ALEMANIA            2018                   COQUIMBO
# 2    H  00 A 04  ALEMANIA            2018                      MAULE
# 3    H  00 A 04  ALEMANIA            2018  METROPOLITANA DE SANTIAGO
# 4    H  00 A 04  ALEMANIA            2018  METROPOLITANA DE SANTIAGO
#
#              COMUNA  CENSO AJUSTADO  RRAA_REGULAR  RRAA_IRREGULAR  RRAA_TOTAL  \
# 0     OTRAS COMUNAS             9.0           1.0             NaN         1.0
# 1         LA SERENA             2.0           NaN             NaN         NaN
# 2            CURICÓ             1.0           NaN             NaN         NaN
# 3  ESTACIÓN CENTRAL             1.0           NaN             NaN         NaN
# 4        LAS CONDES             3.0           NaN             NaN         NaN
#
#    ESTIMACION
# 0          10
# 1           2
# 2           1
# 3           1
# 4           3

# %%
print(df.describe())
# Out:
#        AÑO ESTIMACION  CENSO AJUSTADO  RRAA_REGULAR  RRAA_IRREGULAR  \
# count   123986.000000   113813.000000  74611.000000    20375.000000
# mean      2020.012469       34.374544     44.765504       10.488098
# std          1.411875      144.748952    270.242135      132.159791
# min       2018.000000        1.000000      1.000000        1.000000
# 25%       2019.000000        2.000000      1.000000        1.000000
# 50%       2020.000000        5.000000      4.000000        1.000000
# 75%       2021.000000       19.000000     17.000000        3.000000
# max       2022.000000     6289.000000  10904.000000     8381.000000
#
#          RRAA_TOTAL     ESTIMACION
# count  76931.000000  123986.000000
# mean      46.193264      60.216186
# std      279.740904     321.739695
# min        1.000000       1.000000
# 25%        1.000000       2.000000
# 50%        4.000000       7.000000
# 75%       17.000000      28.000000
# max    10912.000000   14712.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123986 entries, 0 to 123985
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEXO            123986 non-null  object
#  1   EDAD            123986 non-null  object
#  2   PAIS            123986 non-null  object
#  3   AÑO ESTIMACION  123986 non-null  int64
#  4   REGION          120391 non-null  object
#  5   COMUNA          123986 non-null  object
#  6   CENSO AJUSTADO  113813 non-null  float64
#  7   RRAA_REGULAR    74611 non-null   float64
#  8   RRAA_IRREGULAR  20375 non-null   float64
#  9   RRAA_TOTAL      76931 non-null   float64
#  10  ESTIMACION      123986 non-null  int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 10.4+ MB
# None

# %%
print(df.isnull().sum())
# Out:
# SEXO                   0
# EDAD                   0
# PAIS                   0
# AÑO ESTIMACION         0
# REGION              3595
# COMUNA                 0
# CENSO AJUSTADO     10173
# RRAA_REGULAR       49375
# RRAA_IRREGULAR    103611
# RRAA_TOTAL         47055
# ESTIMACION             0
# dtype: int64

# %%
df_clean = df.dropna()

# %%
clean_file_path = '/content/drive/My Drive/GRAFICA/base-2022-comunas-limpio.csv'

df_clean.to_csv(clean_file_path, index =False)
